# %% [markdown]
# # I. Introduction

# %% [markdown]
# This exercise investigates selection sort times for lists of various types and lengths.
#
# First we import helpful packages.

# %%
import random
import numpy as np
import pandas as pd
import time
import string
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # II. Defining the Sort Functions

# %% [markdown]
# Next I leveraged the base code for Selection Sort as described in Chapter 2 of Grokking Algorithms (Bhargava 2016).  https://github.com/egonSchiele/grokking_algorithms/blob/master/02_selection_sort/python/01_selection_sort.py

# %%
# Finds the smallest value in an array
def findSmallest(arr):
  # Initializes the index of the smallest value
  smallest_index = 0
  # Initializes the smallest value
  smallest = arr[0]
  
  # Searches & determines the actual smallest index in the array
  for i in range(1, len(arr)):
    if arr[i] < smallest:
      smallest_index = i
      smallest = arr[i]      
  return smallest_index

# %%
# Sorts list
def selectionSort(workArr):
  # Initializes sorted array
  newArr = []
  
  # Cycles through all elements in the existing unsorted list
  for i in range(len(workArr)):
      # Finds the smallest element in the existing unsorted list, adds it to the new sorted array, and removes it from the existing unsorted list
      smallest = findSmallest(workArr)
      newArr.append(workArr.pop(smallest))
  return newArr

# %% [markdown]
# # III. Generating the Test Data

# %% [markdown]
# After conducting a test run, I was curious to expand the array sizes to 30,000 as well.  Thus, *six* arrays of different sizes (ranging from 5,000 to 30,000) were generated for each of 4 data types, for a total of 25 test arrays.

# %%
# Generates Test Data and stores each test data list within a single list for easy access
sizes = [5000,10000,15000,20000,25000,30000]
test_data = []

for size in sizes:
    np.random.seed(4)
    int_array = list(np.random.randint(1,1000000,size))
    test_data.append(int_array)
    np.random.seed(4)
    dec_array = list(np.random.random(size))
    test_data.append(dec_array)
    np.random.seed(4)
    string5_array = list([''.join(random.choices(string.ascii_letters, k = 5)) for _ in range(size)])
    test_data.append(string5_array)
    np.random.seed(4)
    string15_array = list([''.join(random.choices(string.ascii_letters, k = 15)) for _ in range(size)])
    test_data.append(string15_array)

# %% [markdown]
# # IV. Selection Sort Time Testing

# %% [markdown]
# Wall time for performing the Selection Sort function was measured for each of the 25 arrays individually.
#
# Results are organized into a dataframe capturing the data type of the tested array, the size of the array, the average time taken to sort the array, and the standard deviation of the time taken to sort the array via our python selection sort function.

# %%
# Tests & captures results data
## Initializes Results Capture Data Structure
result_rows = []
result_columns = ['Data_Type','Array_Size','Avg_SelectionSort_Execution_Time_in_ms','StdDev_SelectionSort_Execution_Time_in_ms']

## Captures results for arrays of size 5000
## Uses copies of the generated data so as not alter it via the 'pop' command in the selectionSort function, to allow for continue testing
data_copy = test_data[0].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['int',sizes[0],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[1].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['dec',sizes[0],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[2].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['string5',sizes[0],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[3].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['string15',sizes[0],timeit_data.average*1000,timeit_data.stdev*1000])

## Captures results for arrays of size 10000
data_copy = test_data[4].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['int',sizes[1],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[5].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['dec',sizes[1],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[6].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['string5',sizes[1],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[7].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['string15',sizes[1],timeit_data.average*1000,timeit_data.stdev*1000])

## Captures results for arrays of size 15000
data_copy = test_data[8].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['int',sizes[2],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[9].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['dec',sizes[2],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[10].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['string5',sizes[2],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[11].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['string15',sizes[2],timeit_data.average*1000,timeit_data.stdev*1000])

## Captures results for arrays of size 20000
data_copy = test_data[12].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['int',sizes[3],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[13].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['dec',sizes[3],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[14].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['string5',sizes[3],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[15].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['string15',sizes[3],timeit_data.average*1000,timeit_data.stdev*1000])

## Captures results for arrays of size 25000
data_copy = test_data[16].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['int',sizes[4],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[17].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['dec',sizes[4],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[18].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['string5',sizes[4],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[19].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['string15',sizes[4],timeit_data.average*1000,timeit_data.stdev*1000])

## Captures results for arrays of size 30000
data_copy = test_data[20].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['int',sizes[5],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[21].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['dec',sizes[5],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[22].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['string5',sizes[5],timeit_data.average*1000,timeit_data.stdev*1000])

data_copy = test_data[23].copy()
timeit_data = %timeit -o selectionSort(data_copy)
result_rows.append(['string15',sizes[5],timeit_data.average*1000,timeit_data.stdev*1000])
# Out:
# The slowest run took 4.00 times longer than the fastest. This could mean that an intermediate result is being cached.
# 514 ns ± 285 ns per loop (mean ± std. dev. of 7 runs, 1 loop each)
# The slowest run took 4.00 times longer than the fastest. This could mean that an intermediate result is being cached.
# 500 ns ± 293 ns per loop (mean ± std. dev. of 7 runs, 1 loop each)
# The slowest run took 5.00 times longer than the fastest. This could mean that an intermediate result is being cached.
# 543 ns ± 392 ns per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 500 ns ± 251 ns per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 543 ns ± 350 ns per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 543 ns ± 311 ns per loop (mean ± std. dev. of 7 runs, 1 loop each)
# The slowest run took 4.33 times longer than the fastest. This could mean that an intermediate result is being cached.
# 529 ns ± 319 ns per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ...

# %%
timeit_data.average*1000
# Out:
# 0.0006714285681092795

# %%
# Tests & captures results data
## Initializes Results Capture Data Structure
result_rows = []
result_columns = ['Data_Type','Array_Size','Avg_SelectionSort_Execution_Time_in_ms','StdDev_SelectionSort_Execution_Time_in_ms']

## Captures results for arrays of size 5000
timeit_data = %timeit -o selectionSort(test_data[0])
result_rows.append(['int',sizes[0],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[1])
result_rows.append(['dec',sizes[0],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[2])
result_rows.append(['string5',sizes[0],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[3])
result_rows.append(['string15',sizes[0],timeit_data.average*1000,timeit_data.stdev*1000])

## Captures results for arrays of size 10000
timeit_data = %timeit -o selectionSort(test_data[4])
result_rows.append(['int',sizes[1],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[5])
result_rows.append(['dec',sizes[1],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[6])
result_rows.append(['string5',sizes[1],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[7])
result_rows.append(['string15',sizes[1],timeit_data.average*1000,timeit_data.stdev*1000])

## Captures results for arrays of size 15000
timeit_data = %timeit -o selectionSort(test_data[8])
result_rows.append(['int',sizes[2],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[9])
result_rows.append(['dec',sizes[2],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[10])
result_rows.append(['string5',sizes[2],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[11])
result_rows.append(['string15',sizes[2],timeit_data.average*1000,timeit_data.stdev*1000])

## Captures results for arrays of size 20000
timeit_data = %timeit -o selectionSort(test_data[12])
result_rows.append(['int',sizes[3],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[13])
result_rows.append(['dec',sizes[3],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[14])
result_rows.append(['string5',sizes[3],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[15])
result_rows.append(['string15',sizes[3],timeit_data.average*1000,timeit_data.stdev*1000])

## Captures results for arrays of size 25000
timeit_data = %timeit -o selectionSort(test_data[16])
result_rows.append(['int',sizes[4],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[17])
result_rows.append(['dec',sizes[4],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[18])
result_rows.append(['string5',sizes[4],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[19])
result_rows.append(['string15',sizes[4],timeit_data.average*1000,timeit_data.stdev*1000])

## Captures results for arrays of size 30000
timeit_data = %timeit -o selectionSort(test_data[20])
result_rows.append(['int',sizes[5],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[21])
result_rows.append(['dec',sizes[5],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[22])
result_rows.append(['string5',sizes[5],timeit_data.average*1000,timeit_data.stdev*1000])

timeit_data = %timeit -o selectionSort(test_data[23])
result_rows.append(['string15',sizes[5],timeit_data.average*1000,timeit_data.stdev*1000])
# Out:
# 1.59 s ± 146 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.76 s ± 158 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.46 s ± 238 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.36 s ± 243 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 5.66 s ± 249 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 6.32 s ± 562 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 5.44 s ± 616 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 6.51 s ± 424 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 15.4 s ± 529 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 16.1 s ± 173 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 15.1 s ± 650 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 15.1 s ± 211 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 26.8 s ± 652 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 28.4 s ± 638 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ...

# %%
## Organizes results into pandas dataframe
results = pd.DataFrame(result_rows, columns=result_columns)
results
# Out:
#    Data_Type  Array_Size  Avg_SelectionSort_Execution_Time_in_ms  \
# 0        int        5000                                0.000514
# 1        dec        5000                                0.000500
# 2    string5        5000                                0.000543
# 3   string15        5000                                0.000500
# 4        int       10000                                0.000543
# 5        dec       10000                                0.000543
# 6    string5       10000                                0.000529
# 7   string15       10000                                0.000486
# 8        int       15000                                0.000586
# 9        dec       15000                                0.000529
# 10   string5       15000                                0.000571
# 11  string15       15000                                0.000543
# 12       int       20000                                0.000571
# ...

# %% [markdown]
# # V. Results Analysis

# %% [markdown]
# I used to Seaborn to generate an initial 'results' plot of average execution time in ms (with the standard deviation shown using error bars) by list size, and color coded by list data type.

# %%
# Graphs the results
sns.set()
main_plot = sns.catplot(x="Array_Size"
                        , y="Avg_SelectionSort_Execution_Time_in_ms"
                        , ci = "StdDev_SelectionSort_Execution_Time_in_ms"
                        , hue="Data_Type"
                        , kind="swarm"
                        , data=results)
main_plot.set(ylim=(.00045, .0008))

# %%
## Organizes results into pandas dataframe
results[results['Data_Type'] == 'int']
# Out:
#    Data_Type  Array_Size  Avg_SelectionSort_Execution_Time_in_ms  \
# 0        int        5000                                0.000914
# 4        int       10000                                0.000971
# 8        int       15000                                0.000929
# 12       int       20000                                0.000957
# 16       int       25000                                0.000386
# 20       int       30000                                0.000457
#
#     StdDev_SelectionSort_Execution_Time_in_ms
# 0                                    0.000494
# 4                                    0.000587
# 8                                    0.000534
# 12                                   0.000637
# 16                                   0.000336
# 20                                   0.000266

# %%
## Organizes results into pandas dataframe
results[results['Data_Type'] == 'dec']
# Out:
#    Data_Type  Array_Size  Avg_SelectionSort_Execution_Time_in_ms  \
# 1        dec        5000                                0.000886
# 5        dec       10000                                0.000957
# 9        dec       15000                                0.000886
# 13       dec       20000                                0.000986
# 17       dec       25000                                0.000514
# 21       dec       30000                                0.000471
#
#     StdDev_SelectionSort_Execution_Time_in_ms
# 1                                    0.000461
# 5                                    0.000481
# 9                                    0.000582
# 13                                   0.000500
# 17                                   0.000327
# 21                                   0.000260

# %%
## Organizes results into pandas dataframe
results[results['Data_Type'] == 'string5']
# Out:
#    Data_Type  Array_Size  Avg_SelectionSort_Execution_Time_in_ms  \
# 2    string5        5000                                0.000886
# 6    string5       10000                                0.000871
# 10   string5       15000                                0.000957
# 14   string5       20000                                0.001114
# 18   string5       25000                                0.000457
# 22   string5       30000                                0.000386
#
#     StdDev_SelectionSort_Execution_Time_in_ms
# 2                                    0.000503
# 6                                    0.000423
# 10                                   0.000592
# 14                                   0.000364
# 18                                   0.000266
# 22                                   0.000253

# %%
## Organizes results into pandas dataframe
results[results['Data_Type'] == 'string15']
# Out:
#    Data_Type  Array_Size  Avg_SelectionSort_Execution_Time_in_ms  \
# 3   string15        5000                                0.000957
# 7   string15       10000                                0.000871
# 11  string15       15000                                0.000914
# 15  string15       20000                                0.000343
# 19  string15       25000                                0.000486
# 23  string15       30000                                0.000443
#
#     StdDev_SelectionSort_Execution_Time_in_ms
# 3                                    0.000634
# 7                                    0.000471
# 11                                   0.000574
# 15                                   0.000192
# 19                                   0.000376
# 23                                   0.000311

# %% [markdown]
# Discuss the differences in timing and how they relate to data type and length of array.

# %%
#more graphs

# %% [markdown]
# Prepare an executive summary of your results, referring to the table and figures you have generated. Explain how your results relate to big O notation. Describe your results in language that management can understand. This summary should be included as text paragraphs in the Jupyter notebook. Explain how the algorithm works and why it is a useful to data engineers.
